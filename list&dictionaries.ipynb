# %%
l=[]
print(l)
print(type(l))
# Out:
# []
# <class 'list'>

# %%
l=[1,2,3,4,5,6]
print(l)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l.append(7)
print(l)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 7, 7, 7]

# %%
l.insert(1,8)
print(l)
# Out:
# [1, 8, 2, 3, 4, 5, 6, 7, 7, 7, 7]

# %%
l.pop()
print(l)
# Out:
# [1, 8, 2, 3, 4, 5, 6, 7, 7, 7]

# %%
l.pop(1)
print(l)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 7, 7]

# %%
l.remove(5)
print(l)
# Out:
# [1, 2, 3, 4, 6, 7, 7, 7]

# %%
l1=[1,2,3]
l2=[4,5,6]
l1.append(l2)
print(l1)
# Out:
# [1, 2, 3, [4, 5, 6]]

# %%
l1=[1,2,3]
l2=[4,5,6]
l1.extend(l2)
print(l1)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l=[1,2,3,4,5]
print(l)
# Out:
# [1, 2, 3, 4, 5]

# %%
l.clear()
print(l)
# Out:
# []

# %%
del l

# %%
print(l)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 print(l)
#
# NameError: name 'l' is not defined

# %%
l=[1,5,6,8,2,8,9]
l.sort()
print(l)
# Out:
# [1, 2, 5, 6, 8, 8, 9]

# %%
l=[1,5,6,8,2,8,9]
print(sorted(l))
# Out:
# [1, 2, 5, 6, 8, 8, 9]

# %%
l=[1,5,6,8,2,8,9]
l.reverse()
print(l)
# Out:
# [9, 8, 2, 8, 6, 5, 1]

# %% [markdown]
# Dictionary

# %%
d={}
print(d)
print(type(d))
# Out:
# {}
# <class 'dict'>

# %%
d={"name":"Pavani","city":"Kakinada"}
print(d)
# Out:
# {'name': 'Pavani', 'city': 'Kakinada'}

# %%
print(d["name"])
# Out:
# Pavani

# %%
d["mobile_name"]=123456789
print(d)
# Out:
# {'name': 'Pavani', 'city': 'Kakinada', 'mobile_name': 123456789}

# %%
d["city"]="hyd"
print(d)
# Out:
# {'name': 'Pavani', 'city': 'hyd', 'mobile_name': 123456789}

# %%
print(d.keys())
# Out:
# dict_keys(['name', 'city', 'mobile_name'])

# %%
print(d.values())
# Out:
# dict_values(['Pavani', 'hyd', 123456789])

# %%
print(d.items())
# Out:
# dict_items([('name', 'Pavani'), ('city', 'hyd'), ('mobile_name', 123456789)])

# %%
f=open('abc.txt','w')
print('File name : ',f.name)
print('File mode : ',f.mode)
print(f.readable())
print(f.writable())
print(f.closed)
f.close()
print(f.close)
# Out:
# File name :  abc.txt
# File mode :  w
# False
# True
# False
# <built-in method close of _io.TextIOWrapper object at 0x000001E45214DE00>

# %%
with open("abc.txt","r") as file:
    content = file.read()
print(content)
# Out:
# Aditya Degree College

# %%
with open("abc.txt","r") as file:
    content = file.read(10)
print(content)
# Out:
# Aditya Deg

# %%
with open("abc.txt","r") as file:
    content = file.readline()
print(content)
# Out:
# Aditya Degree College

# %%
with open("abc.txt","r") as file:
    content = file.readlines()
print(content)
# Out:
# ['Aditya Degree College\n']

# %%
with open("abc.txt","w") as file:
    file.write("Aditya Degree college")

# %%
l=["Aditya Degree College\n","Kakinada\n","Andhra pradesh\n"]
with open("abc.txt","w") as file:
   file.writelines(l)

# %%
with open("abc.txt","a") as file:
    file.write("533003")
